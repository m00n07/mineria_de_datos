# %% [markdown]
# <a href="https://colab.research.google.com/github/m00n07/mineria_de_datos/blob/main/Primer_parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Examen Primer Parcial

# %%
# Pregunta 9
import numpy as np
from sklearn.metrics import mean_squared_error

observados = np.array([3, 7, 5, 10])
predichos = np.array([2, 8, 4, 9])

rmse_manual = np.sqrt(np.mean((observados - predichos)**2))

mse = mean_squared_error(observados, predichos)
rmse_sklearn = np.sqrt(mse)

print(f"El RMSE calculado manualmente es: {rmse_manual}")
print(f"El RMSE usando sklearn es: {rmse_sklearn}")
# Out:
# El RMSE calculado manualmente es: 1.0
# El RMSE usando sklearn es: 1.0

# %%
# Pregunta 10

p_a = 0.60  # Máquina A
p_b = 0.40  # Máquina B

p_defectuosa_dado_a = 0.02  # P(D|A)
p_defectuosa_dado_b = 0.05  # P(D|B)

# Fórmula: P(D) = P(A)*P(D|A) + P(B)*P(D|B)
p_defectuosa_total = (p_a * p_defectuosa_dado_a) + (p_b * p_defectuosa_dado_b)

# Fórmula: P(B|D) = (P(B) * P(D|B)) / P(D)
p_b_dado_defectuosa = (p_b * p_defectuosa_dado_b) / p_defectuosa_total

print(f"Probabilidad de que una pieza sea defectuosa: {p_defectuosa_total:.3f} (3.2%)")
print("-" * 50)
print(f"La probabilidad de que la pieza haya sido fabricada por la máquina B es: {p_b_dado_defectuosa:.4f}")
print(f"En porcentaje: {p_b_dado_defectuosa * 100:.2f}%")
# Out:
# Probabilidad de que una pieza sea defectuosa: 0.032 (3.2%)
# --------------------------------------------------
# La probabilidad de que la pieza haya sido fabricada por la máquina B es: 0.6250
# En porcentaje: 62.50%

# %%
import pandas as pd
import numpy as np


# Establece una semilla para reproducibilidad
np.random.seed(42)


# 1. Crea una lista de matrículas de estudiantes
student_ids = [f'{i:06d}' for i in range(172120, 172120 + 20)]


# 2. Asigna 10 estudiantes al grupo 'Café' y 10 al grupo 'Agua'
groups = ['Café'] * 10 + ['Agua'] * 10
np.random.shuffle(groups)


# 3. Simula calificacionen de examenes para el grupo café
# Mean=70, Std=5, asegurate de que los valores estén entre (50-100)
coffee_scores = np.random.normal(loc=70, scale=5, size=10).round(0)
coffee_scores = np.clip(coffee_scores, 50, 100).astype(int)


# 4. Simula calificaciones de examen para el grupo de 'Agua'
# Mean=75, Std=5, asegurate de que los valores estén entre (50-100)
water_scores = np.random.normal(loc=75, scale=5, size=10).round(0)
water_scores = np.clip(water_scores, 50, 100).astype(int)


# Combina los valores basado en el grupo
exam_scores = []
coffee_idx = 0
water_idx = 0
for group in groups:
    if group == 'Café':
        exam_scores.append(coffee_scores[coffee_idx])
        coffee_idx += 1
    else:
        exam_scores.append(water_scores[water_idx])
        water_idx += 1


# 5. Combina en un DataFrame de Pandas
df_students = pd.DataFrame({
    'Matrícula': student_ids,
    'Grupo': groups,
    'Calificaciones': exam_scores
})


print("Datos simulados:")
print(df_students.head())
# Out:
# Datos simulados:
#   Matrícula Grupo  Calificaciones
# 0    172120  Café              77
# 1    172121  Agua              77
# 2    172122  Agua              79
# 3    172123  Café              78
# 4    172124  Café              58

# %%
# Pregunta 13
media_agua = df_students[df_students['Grupo'] == 'Agua']['Calificaciones'].mean()


print(f"Q13 - Media del grupo de Agua: {media_agua}")
# Out:
# Q13 - Media del grupo de Agua: 74.9

# %%
# Pregunta 14
media_cafe = df_students[df_students['Grupo'] == 'Café']['Calificaciones'].mean()

print(f"Q14 - Media del grupo de Café: {media_cafe}")
# Out:
# Q14 - Media del grupo de Café: 70.6

# %%
import pandas as pd

data = {
    'Aprobó': [45, 20],
    'Reprobó': [5, 30],
    'Total': [50, 50]
}
df = pd.DataFrame(data, index=['Tomó el curso', 'No tomó el curso'])

total_estudiantes = 100

# %%
# Pregunta 19
p_interseccion = 45 / total_estudiantes
p_curso = 50 / total_estudiantes
p_condicional = p_interseccion / p_curso

print(f"Resultado Pregunta 19 (P(A|B)): {p_condicional}")
# Out:
# Resultado Pregunta 19 (P(A|B)): 0.9

# %%
# Pregunta 20
p_simple_aprobar = 65 / total_estudiantes

print(f"Resultado Pregunta 20 (P(A)): {p_simple_aprobar}")
# Out:
# Resultado Pregunta 20 (P(A)): 0.65
